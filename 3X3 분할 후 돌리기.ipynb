# %%
from PIL import Image
import cv2
import numpy as np
import time
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import transforms
import albumentations
from matplotlib import pyplot as plt

albumentations_transform_oneof = albumentations.Compose([
    albumentations.Resize(256, 256), 
    albumentations.RandomCrop(224, 224),
    albumentations.OneOf([
                          albumentations.HorizontalFlip(p=0.5),
                          albumentations.RandomRotate90(p=0.5),
                          albumentations.VerticalFlip(p=0.5)            
    ], p=1),
    albumentations.OneOf([
                          albumentations.MotionBlur(p=1),
                          albumentations.OpticalDistortion(p=1),
                          albumentations.GaussNoise(p=1)                 
    ], p=1),
   
])

# %%
class AlbumentationsDataset(Dataset):
    """__init__ and __len__ functions are the same as in TorchvisionDataset"""
    def __init__(self, file_paths, labels, transform=None):
        self.file_paths = file_paths
        self.labels = labels
        self.transform = transform
        
    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        label = self.labels[idx]
        file_path = self.file_paths[idx]
        
        # Read an image with OpenCV
        image = cv2.imread(file_path)
        
        # By default OpenCV uses BGR color space for color images,
        # so we need to convert the image to RGB color space.
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        start_t = time.time()
        if self.transform:
            augmented = self.transform(image=image) 
            image = augmented['image']
            total_time = (time.time() - start_t)
        return image, label, total_time

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/1.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/2.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/3.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/4.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/5.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/6.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/7.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/8.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')

# %%
albumentations_dataset = AlbumentationsDataset(
    file_paths=["3X3/9.jpg"],
    labels=[1],
    transform=albumentations_transform_oneof,
)

num_samples = 8
fig, ax = plt.subplots(1, num_samples, figsize=(25, 5))
for i in range(num_samples):
  ax[i].imshow(transforms.ToPILImage()(albumentations_dataset[0][0]))
  ax[i].axis('off')
